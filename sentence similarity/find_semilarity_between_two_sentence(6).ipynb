# %%
# !pip install -U jupyterlab pandas datasets matplotlib plotly scikit-learn tqdm ipywidgets
# !pip install -U numpy spacy textdistance fasttext gensim
# !pip install -U tensorflow tensorflow_hub sentence-transformers openai
# !conda install pyemd

# Download the Spacy Model
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 12.2 MB 51.2 MB/s
# ...
#      |████████████████████████████████| 452 kB 70.3 MB/s
# ...
#      |████████████████████████████████| 9.4 MB 22.5 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 60.4 MB/s
# ...
#      |████████████████████████████████| 9.7 MB 63.3 MB/s
# ...
#      |████████████████████████████████| 137 kB 47.1 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 361 kB 48.4 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 64.9 MB/s
# ...
#      |████████████████████████████████| 423 kB 71.6 MB/s
# ...
#      |████████████████████████████████| 273 kB 76.9 MB/s
# ...
#      |████████████████████████████████| 55 kB 120 kB/s
# ...
#      |████████████████████████████████| 133 kB 56.9 MB/s
# ...
#      |████████████████████████████████| 80 kB 8.7 MB/s
# ...

# %%
# Imports
from datasets import load_dataset
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()

# %%
# Load the English STSB dataset
stsb_dataset = load_dataset('stsb_multi_mt', 'en')
stsb_train = pd.DataFrame(stsb_dataset['train'])
stsb_test = pd.DataFrame(stsb_dataset['test'])
stsb_train.to_csv("stsb_train")
stsb_test.to_csv("stsb_test")
# Check loaded data
print(stsb_train.shape, stsb_test.shape)
stsb_test.head()
# Out:
# ...
# Generating dev split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Dataset stsb_multi_mt downloaded and prepared to /root/.cache/huggingface/datasets/stsb_multi_mt/en/1.0.0/a5d260e4b7aa82d1ab7379523a005a366d9b124c76a5a5cf0c4c5365458b0ba9. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# (5749, 3) (1379, 3)
#                                        sentence1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
#
#                                           sentence2  similarity_score
# 0                      A girl is brushing her hair.               2.5
# 1  A group of boys are playing soccer on the beach.               3.6
# 2           A woman measures another woman's ankle.               5.0
# ...

# %%
stsb_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 5749
#     })
#     test: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 1379
#     })
#     dev: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 1500
#     })
# })

# %%
print(type(stsb_dataset))
# Out:
# <class 'datasets.dataset_dict.DatasetDict'>

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2022-12-22 15:41:33.474286: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-22 15:41:33.474522: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
from textblob import TextBlob
import spacy
nlp = spacy.load("en_core_web_sm")

def text_processing(sentence):
    """
    Lemmatize, lowercase, remove numbers and stop words

    Args:
      sentence: The sentence we want to process.

    Returns:
      A list of processed words
    """
    sentence = ''.join(TextBlob(sentence).correct())
    # print(sentence)
    sentence = [token.lemma_.lower()
                for token in nlp(sentence)
                if token.is_alpha and not token.is_stop]


    return sentence


def find_number_of_common_word(sentence_one_list,sentence_two_list):
        # print(sentence_one_list)
        # print(type(eval(sentence_one_list)))
        return len(set(sentence_one_list)&set(sentence_two_list))

def cos_sim(sentence1_emb, sentence2_emb):
    """
    Cosine similarity between two columns of sentence embeddings

    Args:
      sentence1_emb: sentence1 embedding column
      sentence2_emb: sentence2 embedding column

    Returns:
      The row-wise cosine similarity between the two columns.
      For instance is sentence1_emb=[a,b,c] and sentence2_emb=[x,y,z]
      Then the result is [cosine_similarity(a,x), cosine_similarity(b,y), cosine_similarity(c,z)]
    """
    cos_sim = cosine_similarity(sentence1_emb, sentence2_emb)
    return np.diag(cos_sim)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
print(stsb_train.shape)
# Out:
# (5749, 3)

# %%
stsb_train['sentence1'] = stsb_train['sentence1'].apply(lambda cw : text_processing(cw))
stsb_train['sentence2'] = stsb_train['sentence2'].apply(lambda cw : text_processing(cw))
stsb_train.to_csv("stsb_train_clean.csv")

# %%
stsb_train.head()
# Out:
#                                sentence1  \
# 0                          [plane, take]
# 1              [man, play, large, flute]
# 2  [man, spread, screwed, cheese, penza]
# 3                     [man, play, chess]
# 4                      [man, play, cell]
#
#                                           sentence2  similarity_score
# 0                                [air, plane, take]              5.00
# 1                                [man, play, flute]              3.80
# 2  [man, spread, shrouded, cheese, unhooked, penza]              3.80
# 3                                [man, play, chess]              2.60
# 4                           [man, seat, play, cell]              4.25

# %%
stsb_train['common_word']  = stsb_train.apply(lambda row : find_number_of_common_word(row[0],row[1]),axis=1)
stsb_train.head(10)
# Out:
#                                sentence1  \
# 0                          [plane, take]
# 1              [man, play, large, flute]
# 2  [man, spread, screwed, cheese, penza]
# 3                     [man, play, chess]
# 4                      [man, play, cell]
# 5                           [man, fight]
# 6                           [man, smoke]
# 7                     [man, play, piano]
# 8           [man, play, guitar, singing]
# 9          [person, throw, cat, ceiling]
#
#                                           sentence2  similarity_score  \
# 0                                [air, plane, take]              5.00
# 1                                [man, play, flute]              3.80
# 2  [man, spread, shrouded, cheese, unhooked, penza]              3.80
# 3                                [man, play, chess]              2.60
# 4                           [man, seat, play, cell]              4.25
# 5                                      [man, fight]              4.25
# ...

# %%
def ranking(ser_of_data):
    array = np.array(ser_of_data)
    temp = array.argsort()
    ranks = np.empty_like(temp)
    ranks[temp] = np.arange(len(array))
    ranks = 1 + ranks
    # print(sorted(ranks))
    return ranks

stsb_train['rank_by_common_word'] = ranking(stsb_train['common_word'])
stsb_train.head(10)

# %%
stsb_train['rank_by_similarity_score'] = ranking(stsb_train['similarity_score'])
stsb_train.head(10)
# Out:
#                                sentence1  \
# 0                          [plane, take]
# 1              [man, play, large, flute]
# 2  [man, spread, screwed, cheese, penza]
# 3                     [man, play, chess]
# 4                      [man, play, cell]
# 5                           [man, fight]
# 6                           [man, smoke]
# 7                     [man, play, piano]
# 8           [man, play, guitar, singing]
# 9          [person, throw, cat, ceiling]
#
#                                           sentence2  similarity_score  \
# 0                                [air, plane, take]              5.00
# 1                                [man, play, flute]              3.80
# 2  [man, spread, shrouded, cheese, unhooked, penza]              3.80
# 3                                [man, play, chess]              2.60
# 4                           [man, seat, play, cell]              4.25
# 5                                      [man, fight]              4.25
# ...

# %%
stsb_train['d'] = stsb_train.apply(lambda row : row[4] - row[5] ,axis=1)
stsb_train['d^2'] = stsb_train.apply(lambda row : row[6]**2,axis=1)
stsb_train.head(10)
# Out:
#                                sentence1  \
# 0                          [plane, take]
# 1              [man, play, large, flute]
# 2  [man, spread, screwed, cheese, penza]
# 3                     [man, play, chess]
# 4                      [man, play, cell]
# 5                           [man, fight]
# 6                           [man, smoke]
# 7                     [man, play, piano]
# 8           [man, play, guitar, singing]
# 9          [person, throw, cat, ceiling]
#
#                                           sentence2  similarity_score  \
# 0                                [air, plane, take]              5.00
# 1                                [man, play, flute]              3.80
# 2  [man, spread, shrouded, cheese, unhooked, penza]              3.80
# 3                                [man, play, chess]              2.60
# 4                           [man, seat, play, cell]              4.25
# 5                                      [man, fight]              4.25
# ...

# %%
r = 1 - (6*stsb_train['d^2'].sum())/(pow(len(stsb_train['d^2']),3) - len(stsb_train['d^2']))
stsb_train.to_csv("stsb_train_a.csv")
print(r)
# Out:
# 0.5773636963561097

# %%
new_stsb_train = pd.read_csv('stsb_train_clean.csv',index_col = [0])

new_stsb_train['sentence1'] = new_stsb_train['sentence1'].apply(lambda cw : eval(cw))
new_stsb_train['sentence2'] = new_stsb_train['sentence2'].apply(lambda cw : eval(cw))

new_stsb_train['sentence1'] = new_stsb_train['sentence1'].apply(lambda cw : " ".join(cw))
new_stsb_train['sentence2'] = new_stsb_train['sentence2'].apply(lambda cw : " ".join(cw))


new_stsb_train.head()
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
#
#    similarity_score
# 0              5.00
# 1              3.80
# 2              3.80
# 3              2.60
# 4              4.25

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
model = TfidfVectorizer(lowercase=True, stop_words='english')
# Train the model
X_train = pd.concat([new_stsb_train['sentence1'], new_stsb_train['sentence2']]).unique()
model.fit(X_train)

# # Generate Embeddings on Test
# sentence1_emb = model.transform(stsb_test['sentence1'])
# sentence2_emb = model.transform(stsb_test['sentence2'])
#
# # Cosine Similarity
# stsb_test['TFIDF_cosine_score'] = cos_sim(sentence1_emb, sentence2_emb)
# Out:
# TfidfVectorizer(stop_words='english')

# %%
# Generate Embeddings on Test
sentence1_emb = model.transform(new_stsb_train['sentence1'])
sentence2_emb = model.transform(new_stsb_train['sentence2'])
# Cosine Similarity
new_stsb_train['TFIDF_cosine_score'] = cos_sim(sentence1_emb, sentence2_emb)

new_stsb_train.head()
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
#
#    similarity_score  TFIDF_cosine_score
# 0              5.00            0.721472
# 1              3.80            0.869867
# 2              3.80            0.596340
# 3              2.60            1.000000
# 4              4.25            0.801722

# %%
new_stsb_train['rank_by_TFIDF_cosine_score'] = ranking(new_stsb_train['TFIDF_cosine_score'])
new_stsb_train.head(10)
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
# 5                        man fight                                  man fight
# 6                        man smoke                                  man state
# 7                   man play piano                            man play guitar
# 8          man play guitar singing          woman play caustic guitar singing
# 9         person throw cat ceiling                   person throw cat ceiling
#
#    similarity_score  TFIDF_cosine_score  rank_by_TFIDF_cosine_score
# ...

# %%
new_stsb_train['rank_by_similarity_score'] = ranking(new_stsb_train['similarity_score'])
new_stsb_train.head(10)
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
# 5                        man fight                                  man fight
# 6                        man smoke                                  man state
# 7                   man play piano                            man play guitar
# 8          man play guitar singing          woman play caustic guitar singing
# 9         person throw cat ceiling                   person throw cat ceiling
#
#    similarity_score  TFIDF_cosine_score  rank_by_TFIDF_cosine_score  \
# ...

# %%
new_stsb_train['d'] = new_stsb_train.apply(lambda row : row[4] - row[5] ,axis=1)
new_stsb_train['d^2'] = new_stsb_train.apply(lambda row : row[6]**2,axis=1)
new_stsb_train.head(10)
new_stsb_train.to_csv("new_stsb_train_c.csv")

# %%
r = 1 - (6*new_stsb_train['d^2'].sum())/(pow(len(new_stsb_train['d^2']),3) - len(new_stsb_train['d^2']))
print(r)
# Out:
# 0.6521460459919839

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sentence_transformers import SentenceTransformer

# %%
new_stsb_train_brt = pd.read_csv('stsb_train_clean.csv',index_col = [0])

new_stsb_train_brt['sentence1'] = new_stsb_train_brt['sentence1'].apply(lambda cw : eval(cw))
new_stsb_train_brt['sentence2'] = new_stsb_train_brt['sentence2'].apply(lambda cw : eval(cw))
new_stsb_train_brt.head()
# Out:
#                                sentence1  \
# 0                          [plane, take]
# 1              [man, play, large, flute]
# 2  [man, spread, screwed, cheese, penza]
# 3                     [man, play, chess]
# 4                      [man, play, cell]
#
#                                           sentence2  similarity_score
# 0                                [air, plane, take]              5.00
# 1                                [man, play, flute]              3.80
# 2  [man, spread, shrouded, cheese, unhooked, penza]              3.80
# 3                                [man, play, chess]              2.60
# 4                           [man, seat, play, cell]              4.25

# %%
new_stsb_train_brt['sentence1'] = new_stsb_train_brt['sentence1'].apply(lambda cw : " ".join(cw))
new_stsb_train_brt['sentence2'] = new_stsb_train_brt['sentence2'].apply(lambda cw : " ".join(cw))

# Load the pre-trained model
model = SentenceTransformer('sentence-transformers/stsb-mpnet-base-v2')

# Generate Embeddings
sentence1_emb = model.encode(new_stsb_train_brt['sentence1'], show_progress_bar=True)
sentence2_emb = model.encode(new_stsb_train_brt['sentence2'], show_progress_bar=True)
# Out:
# Downloading:   0%|          | 0.00/868 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.67k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/588 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# ...
# Batches:   0%|          | 0/180 [00:00<?, ?it/s]

# %%
# Cosine Similarity
new_stsb_train_brt['sentence_transformers_cosine_score'] = cos_sim(sentence1_emb, sentence2_emb)

# %%
new_stsb_train_brt.head()
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
#
#    similarity_score  sentence_transformers_cosine_score
# 0              5.00                            0.926049
# 1              3.80                            0.950658
# 2              3.80                            0.714319
# 3              2.60                            1.000000
# 4              4.25                            0.842476

# %%
new_stsb_train_brt['rank_by_similarity_score'] = ranking(new_stsb_train_brt['similarity_score'])
new_stsb_train_brt['rank_by_sentence_transformers_cosine_score'] = ranking(new_stsb_train_brt['sentence_transformers_cosine_score'])
new_stsb_train_brt.head(10)
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
# 5                        man fight                                  man fight
# 6                        man smoke                                  man state
# 7                   man play piano                            man play guitar
# 8          man play guitar singing          woman play caustic guitar singing
# 9         person throw cat ceiling                   person throw cat ceiling
#
#    similarity_score  sentence_transformers_cosine_score  \
# ...

# %%
new_stsb_train_brt['d'] = new_stsb_train_brt.apply(lambda row : row[4] - row[5] ,axis=1)
new_stsb_train_brt['d^2'] = new_stsb_train_brt.apply(lambda row : row[6]**2,axis=1)
new_stsb_train_brt.head(10)
# Out:
#                          sentence1                                  sentence2  \
# 0                       plane take                             air plane take
# 1             man play large flute                             man play flute
# 2  man spread screwed cheese penza  man spread shrouded cheese unhooked penza
# 3                   man play chess                             man play chess
# 4                    man play cell                         man seat play cell
# 5                        man fight                                  man fight
# 6                        man smoke                                  man state
# 7                   man play piano                            man play guitar
# 8          man play guitar singing          woman play caustic guitar singing
# 9         person throw cat ceiling                   person throw cat ceiling
#
#    similarity_score  sentence_transformers_cosine_score  \
# ...

# %%
r = 1 - (6*new_stsb_train_brt['d^2'].sum())/(pow(len(new_stsb_train_brt['d^2']),3) - len(new_stsb_train_brt['d^2']))
print(r)
# Out:
# 0.8005006328318197

# %%
stsb_train_a = pd.read_csv('stsb_train_a.csv',index_col = [0])
stsb_train = pd.read_csv('stsb_train.csv',index_col = [0])


res = stsb_train_a.sort_values('rank_by_common_word')
list_of_top_ten_similar_in_number_commen_word = res[-10:]
# print(list(list_of_top_ten_similar_in_number_commen_word.index))

# %%
#new_stsb_train

res = stsb_train_a.sort_values('rank_by_common_word')
list_of_top_ten_similar_in_number_commen_word_index = list(res[-10:].index)
list_of_botten_ten_similar_in_number_commen_word_index = list(res[:10].index)


res2 = new_stsb_train.sort_values('rank_by_TFIDF_cosine_score') 
list_of_top_ten_similar_in_number_TDIDF_index = list(res2[-10:].index)
list_of_botten_ten_similar_in_number_TDIDF_index = list(res2[:10].index)

res3 = new_stsb_train_brt.sort_values('rank_by_sentence_transformers_cosine_score')
list_of_top_ten_similar_in_number_Pre_train_index = list(res3[-10:].index)
list_of_botten_ten_similar_in_number_Pre_train_index = list(res3[:10].index)

# %%
stsb_train.iloc[list_of_top_ten_similar_in_number_commen_word_index]
# Out:
#                                               sentence1  \
# 3117  Still, the "somewhat ambiguous ruling" might b...
# 2473  Tom Kraynak, manager of operations and resourc...
# 3599  hong kong universities collaborate with univer...
# 3586  saferworld team leader on transfer controls an...
# 3737  the resolution requires all 192 united nations...
# 3641  brazil's strategic affairs minister roberto ma...
# 3467  switzerland's trade and diplomatic relations w...
# 3703  iraq has been lobbying for the security counci...
# 3643  variants of the advanced light helicopter (alh...
# 3605  russian president vladimir putin states that t...
#
#                                               sentence2  similarity_score
# 3117  But Merrill Lynch analyst Steven Milunovich sa...              5.00
# 2473  Tom Kraynak, manager of operations and resourc...              4.25
# 3599  hong kong universities have collaborated with ...              5.00
# ...

# %%
stsb_train.iloc[list_of_botten_ten_similar_in_number_commen_word_index]
# Out:
#                                               sentence1  \
# 5748   Putin spokesman: Doping charges appear unfounded
# 800                               A gun is being fired.
# 4791        Senate to vote on moving ahead on Hagel nod
# 813                       The two dogs were in the pen.
# 4784                 Egypt protesters 'to be dispersed'
# 817                     A man is kicking oots of water.
# 818                                    A man is eating.
# 821                         The woman is peeling lemon.
# 826   Someone is cutting a circle out of a pink shee...
# 829                         A girl is eating a cupcake.
#
#                                               sentence2  similarity_score
# 5748  The Latest on Severe Weather: 1 Dead in Texas ...              0.00
# 800                           A potato is being peeled.              0.50
# 4791      Benedict comes home to new house and new Pope              0.00
# ...

# %%
stsb_train.iloc[list_of_top_ten_similar_in_number_TDIDF_index]
# Out:
#                                               sentence1  \
# 195                            Two dogs swim in a pool.
# 77                      A monkey pushes another monkey.
# 1517                   boy doing tricks on a skateboard
# 2011                 There's no chance of a fair trial.
# 4582  Exclusive-UPDATE 2-Egypt pro-Mursi alliance si...
# 2176                   the problem isn't who has money.
# 2473  Tom Kraynak, manager of operations and resourc...
# 502                  A toy train is striking a toy car.
# 4776                        7 killed in attacks in Iraq
# 5341         Snowden sees 'no chance' for US fair trial
#
#                                               sentence2  similarity_score
# 195                        Dogs are swimming in a pool.          4.200000
# 77                  The monkey pushed the other monkey.          4.800000
# 1517                A boy does a trick on a skateboard.          4.800000
# ...

# %%
stsb_train.iloc[list_of_botten_ten_similar_in_number_TDIDF_index]
# Out:
#                                               sentence1  \
# 5748   Putin spokesman: Doping charges appear unfounded
# 1752  A snowboarder rides a snowboard down a railing...
# 4735  US releases initial report on fracking impacts...
# 1745                 A black dog retrieves in the snow.
# 1739  An old man in a black trench coat standing in ...
# 5437       Many dead as asylum boat sinks off Australia
# 5435  China ‚Äėwill protect interests‚Äô of foreign ...
# 1712                                 Man rowing a boat.
# 1708           Two dogs are playing around in the dirt.
# 1706  A climber is standing on the rock face next to...
#
#                                               sentence2  similarity_score
# 5748  The Latest on Severe Weather: 1 Dead in Texas ...               0.0
# 1752  A boy is grinding a skateboard down a concrete...               0.8
# 4735  Men in China detained after taking girls to hotel               0.0
# ...

# %%
stsb_train.iloc[list_of_top_ten_similar_in_number_Pre_train_index]
# Out:
#                                              sentence1  \
# 575                             A girl jumps on a car.
# 2317    Religion that does that I have a problem with.
# 527                     The dog is barking at the toy.
# 16              The polar bear is sliding on the snow.
# 511                   A woman is brushing some shrimp.
# 4236                   Soldier 'can't recall' massacre
# 3931     Assange appeals extradition to UK's top court
# 5341        Snowden sees 'no chance' for US fair trial
# 4252  Avalanche buries at least 100 Pakistani soldiers
# 247                      The boy is playing the piano.
#
#                                               sentence2  similarity_score
# 575                       A girl is jumping onto a car.               4.8
# 2317  Irreligion that doesn't do that I don't have a...               1.4
# 527                          A dog is barking at a toy.               5.0
# ...

# %%
stsb_train.iloc[list_of_botten_ten_similar_in_number_Pre_train_index]
# Out:
#                                               sentence1  \
# 262                            A man is riding a horse.
# 404                      A man is jumping rope outside.
# 1514                    The two boys play in the field.
# 1422                   Two women are sitting in a cafe.
# 395                   A dog is jumping on a trampoline.
# 335                       A man is breaking water jugs.
# 1578                  Children jumping on a trampoline.
# 1185         Two brown horses standing in grassy field.
# 1857  Four kids holding hands jump into a swimming p...
# 3718  this is particularly true in the poorest count...
#
#                                               sentence2  similarity_score
# 262                       A woman is washing a freezer.               0.0
# 404                      A woman is slicing a cucumber.               0.0
# 1514  The two people have their heads covered with s...               0.0
# ...
